# %% [markdown]
# Architecture was taken from https://github.com/ozanciga/gans-with-pytorch <br>
# UPD: corrected loss function as was mentioned <a href="https://www.kaggle.com/c/generative-dog-images/discussion/99485#latest-573753">here<a/>

# %%
import numpy as np
import pandas as pd
import os
import time
import matplotlib.pyplot as plt

import torch
from torch import nn, optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
from torch.utils.data import Dataset, DataLoader
from PIL import Image

from tqdm import tqdm_notebook as tqdm

# %%
# !pip install --upgrade ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading https://files.pythonhosted.org/packages/25/22/f48bd3af0ef7c72dce13f9930a4483acbc7c77373834700296495ea0875f/ipywidgets-7.8.5-py2.py3-none-any.whl (124kB)
#      |████████████████████████████████| 133kB 8.0MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in /opt/conda/lib/python3.6/site-packages (from ipywidgets) (7.6.1)
# Collecting comm>=0.1.3 (from ipywidgets)
#   Downloading https://files.pythonhosted.org/packages/fe/47/0133ac1b7dc476ed77710715e98077119b3d9bae56b13f6f9055e7da1c53/comm-0.1.4-py3-none-any.whl
# Collecting widgetsnbextension~=3.6.10 (from ipywidgets)
#   Downloading https://files.pythonhosted.org/packages/93/1b/25d570ee8dce0f2ddadb967d6242cf6e10516db7897c7d9a6e3853b56bfc/widgetsnbextension-3.6.10-py2.py3-none-any.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 51.9MB/s eta 0:00:01
# Collecting jupyterlab-widgets<3,>=1.0.0; python_version >= "3.6" (from ipywidgets)
#   Downloading https://files.pythonhosted.org/packages/1f/73/4f281e0f86bf532baec742da40ededf8b22dc224523e38c638fb6ad91255/jupyterlab_widgets-1.1.11-py3-none-any.whl (246kB)
#      |████████████████████████████████| 256kB 55.0MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.6/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in /opt/conda/lib/python3.6/site-packages (from ipywidgets) (4.3.2)
# Requirement already satisfied, skipping upgrade: pygments in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.4.2)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (41.0.1)
# Requirement already satisfied, skipping upgrade: backcall in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.0)
# Requirement already satisfied, skipping upgrade: pickleshare in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.7.0)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.1.0,>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.0.9)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.13.3)
# Requirement already satisfied, skipping upgrade: decorator in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.4.0)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in /opt/conda/lib/python3.6/site-packages (from widgetsnbextension~=3.6.10->ipywidgets) (5.5.0)
# Requirement already satisfied, skipping upgrade: six in /opt/conda/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets) (1.12.0)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /opt/conda/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.6.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /opt/conda/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.7)
# Requirement already satisfied, skipping upgrade: parso>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.5.0)
# Requirement already satisfied, skipping upgrade: nbconvert in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (5.5.0)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (18.0.0)
# Requirement already satisfied, skipping upgrade: ipykernel in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (5.1.1)
# Requirement already satisfied, skipping upgrade: tornado>=4 in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (5.0.2)
# Requirement already satisfied, skipping upgrade: jinja2 in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (2.10.1)
# Requirement already satisfied, skipping upgrade: jupyter-core>=4.4.0 in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (4.5.0)
# Requirement already satisfied, skipping upgrade: Send2Trash in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (1.5.0)
# Requirement already satisfied, skipping upgrade: nbformat in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (4.4.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (0.8.2)
# Requirement already satisfied, skipping upgrade: jupyter-client>=5.2.0 in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (5.2.4)
# Requirement already satisfied, skipping upgrade: bleach in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (3.1.0)
# Requirement already satisfied, skipping upgrade: mistune>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (0.8.4)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (0.3)
# Requirement already satisfied, skipping upgrade: defusedxml in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (0.6.0)
# Requirement already satisfied, skipping upgrade: testpath in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (0.3.1)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (1.4.2)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (1.1.1)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.6/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (3.0.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from jupyter-client>=5.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (2.8.0)
# Requirement already satisfied, skipping upgrade: webencodings in /opt/conda/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (0.5.1)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (19.1.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets) (0.14.11)
# Installing collected packages: comm, widgetsnbextension, jupyterlab-widgets, ipywidgets
#   Found existing installation: widgetsnbextension 3.4.2
#     Uninstalling widgetsnbextension-3.4.2:
#       Successfully uninstalled widgetsnbextension-3.4.2
#   Found existing installation: ipywidgets 7.4.2
#     Uninstalling ipywidgets-7.4.2:
#       Successfully uninstalled ipywidgets-7.4.2
# Successfully installed comm-0.1.4 ipywidgets-7.8.5 jupyterlab-widgets-1.1.11 widgetsnbextension-3.6.10

# %% [markdown]
# # Generator and Discriminator

# %%
class Generator(nn.Module):
    def __init__(self, nz=128, channels=3):
        super(Generator, self).__init__()
        
        self.nz = nz
        self.channels = channels
        
        def convlayer(n_input, n_output, k_size=4, stride=2, padding=0):
            block = [
                nn.ConvTranspose2d(n_input, n_output, kernel_size=k_size, stride=stride, padding=padding, bias=False),
                nn.BatchNorm2d(n_output),
                nn.ReLU(inplace=True),
            ]
            return block

        self.model = nn.Sequential(
            *convlayer(self.nz, 1024, 4, 1, 0), # Fully connected layer via convolution.
            *convlayer(1024, 512, 4, 2, 1),
            *convlayer(512, 256, 4, 2, 1),
            *convlayer(256, 128, 4, 2, 1),
            *convlayer(128, 64, 4, 2, 1),
            nn.ConvTranspose2d(64, self.channels, 3, 1, 1),
            nn.Tanh()
        )


    def forward(self, z):
        z = z.view(-1, self.nz, 1, 1)
        img = self.model(z)
        return img

class Discriminator(nn.Module):
    def __init__(self, channels=3):
        super(Discriminator, self).__init__()
        
        self.channels = channels

        def convlayer(n_input, n_output, k_size=4, stride=2, padding=0, bn=False):
            block = [nn.Conv2d(n_input, n_output, kernel_size=k_size, stride=stride, padding=padding, bias=False)]
            if bn:
                block.append(nn.BatchNorm2d(n_output))
            block.append(nn.LeakyReLU(0.2, inplace=True))
            return block

        self.model = nn.Sequential(
            *convlayer(self.channels, 32, 4, 2, 1),
            *convlayer(32, 64, 4, 2, 1),
            *convlayer(64, 128, 4, 2, 1, bn=True),
            *convlayer(128, 256, 4, 2, 1, bn=True),
            nn.Conv2d(256, 1, 4, 1, 0, bias=False),  # FC with Conv.
        )

    def forward(self, imgs):
        out = self.model(imgs)
        return out.view(-1, 1)

# %% [markdown]
# ## Parameters of GAN

# %%
batch_size = 32
lr = 0.001
beta1 = 0.5
epochs = 500

real_label = 0.5
fake_label = 0
nz = 128

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Data loader and Augmentations

# %%
import os
import shutil

def move_images(source_dir, target_dir, limit=3000):
    # Check if target directory exists, if not, create it
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)

    # Counter for the number of moved images
    moved_count = 0

    # List of files to exclude
    excluded_files = ['10.jpg', '7.jpg']

    # Walk through all directories and subdirectories
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            # Check if the file is an image and not in the excluded list
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')) and file not in excluded_files:
                # Construct full file path
                file_path = os.path.join(root, file)
                
                # Construct the path where the image will be moved
                target_path = os.path.join(target_dir, file)
                
                # Move the image
                shutil.copy(file_path, target_path)
                print(f"Moved: {file_path} -> {target_path}")
                
                # Increment the counter
                moved_count += 1
                
                # Stop after moving the first 'limit' images
                if moved_count >= limit:
                    print(f"Reached the limit of {limit} images.")
                    return

# Set the source directory and the target directory
source_directory = "/kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square"  # Replace with the actual path
target_directory = "/kaggle/working/allimages/shoes"  # Replace with the target folder path

# Move the first 100 images, excluding 10.jpg and 7.jpg
move_images(source_directory, target_directory, limit=4000)
# Out:
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Nike/7525639.191707.jpg -> /kaggle/working/allimages/shoes/7525639.191707.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Nike/7525639.151.jpg -> /kaggle/working/allimages/shoes/7525639.151.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Teva Kids/7592562.275.jpg -> /kaggle/working/allimages/shoes/7592562.275.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Keen Kids/7501314.4535.jpg -> /kaggle/working/allimages/shoes/7501314.4535.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Keen Kids/7397030.4535.jpg -> /kaggle/working/allimages/shoes/7397030.4535.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Keen Kids/7500854.43936.jpg -> /kaggle/working/allimages/shoes/7500854.43936.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Keen/7599282.221016.jpg -> /kaggle/working/allimages/shoes/7599282.221016.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Keen/7599282.55057.jpg -> /kaggle/working/allimages/shoes/7599282.55057.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Keen/7596238.3.jpg -> /kaggle/working/allimages/shoes/7596238.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/Sperry Top-Sider/7266887.18.jpg -> /kaggle/working/allimages/shoes/7266887.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/adidas/7368136.124874.jpg -> /kaggle/working/allimages/shoes/7368136.124874.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/adidas/115220.20569.jpg -> /kaggle/working/allimages/shoes/115220.20569.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/adidas/115220.151.jpg -> /kaggle/working/allimages/shoes/115220.151.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Athletic/adidas/7268762.11682.jpg -> /kaggle/working/allimages/shoes/7268762.11682.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8066558.241941.jpg -> /kaggle/working/allimages/shoes/8066558.241941.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8066558.632.jpg -> /kaggle/working/allimages/shoes/8066558.632.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8066558.106387.jpg -> /kaggle/working/allimages/shoes/8066558.106387.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8066558.314454.jpg -> /kaggle/working/allimages/shoes/8066558.314454.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8068515.7357.jpg -> /kaggle/working/allimages/shoes/8068515.7357.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8066558.18343.jpg -> /kaggle/working/allimages/shoes/8066558.18343.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8069962.388148.jpg -> /kaggle/working/allimages/shoes/8069962.388148.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8069962.388149.jpg -> /kaggle/working/allimages/shoes/8069962.388149.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8068515.106387.jpg -> /kaggle/working/allimages/shoes/8068515.106387.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8066558.35560.jpg -> /kaggle/working/allimages/shoes/8066558.35560.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8068515.32309.jpg -> /kaggle/working/allimages/shoes/8068515.32309.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Rebecca Minkoff/8068447.79453.jpg -> /kaggle/working/allimages/shoes/8068447.79453.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/New Balance Classics/7196336.401.jpg -> /kaggle/working/allimages/shoes/7196336.401.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/New Balance Classics/7196336.139.jpg -> /kaggle/working/allimages/shoes/7196336.139.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7631070.72.jpg -> /kaggle/working/allimages/shoes/7631070.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7824557.3.jpg -> /kaggle/working/allimages/shoes/7824557.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963054.281.jpg -> /kaggle/working/allimages/shoes/7963054.281.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7631070.492.jpg -> /kaggle/working/allimages/shoes/7631070.492.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963040.3.jpg -> /kaggle/working/allimages/shoes/7963040.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963049.35830.jpg -> /kaggle/working/allimages/shoes/7963049.35830.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963032.621.jpg -> /kaggle/working/allimages/shoes/7963032.621.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7631070.15.jpg -> /kaggle/working/allimages/shoes/7631070.15.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7824557.494.jpg -> /kaggle/working/allimages/shoes/7824557.494.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7720633.76276.jpg -> /kaggle/working/allimages/shoes/7720633.76276.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7305596.278.jpg -> /kaggle/working/allimages/shoes/7305596.278.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7631070.6332.jpg -> /kaggle/working/allimages/shoes/7631070.6332.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7397040.128531.jpg -> /kaggle/working/allimages/shoes/7397040.128531.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963032.3.jpg -> /kaggle/working/allimages/shoes/7963032.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7824557.18.jpg -> /kaggle/working/allimages/shoes/7824557.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7305596.3.jpg -> /kaggle/working/allimages/shoes/7305596.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7397040.3.jpg -> /kaggle/working/allimages/shoes/7397040.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7720633.281.jpg -> /kaggle/working/allimages/shoes/7720633.281.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7397040.128530.jpg -> /kaggle/working/allimages/shoes/7397040.128530.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963054.35830.jpg -> /kaggle/working/allimages/shoes/7963054.35830.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7824557.95658.jpg -> /kaggle/working/allimages/shoes/7824557.95658.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963040.278.jpg -> /kaggle/working/allimages/shoes/7963040.278.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963049.281.jpg -> /kaggle/working/allimages/shoes/7963049.281.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7824557.278.jpg -> /kaggle/working/allimages/shoes/7824557.278.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7397040.61167.jpg -> /kaggle/working/allimages/shoes/7397040.61167.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7963032.18.jpg -> /kaggle/working/allimages/shoes/7963032.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/UGG/7631070.411180.jpg -> /kaggle/working/allimages/shoes/7631070.411180.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/7908907.90.jpg -> /kaggle/working/allimages/shoes/7908907.90.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/7908964.90.jpg -> /kaggle/working/allimages/shoes/7908964.90.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074081.94265.jpg -> /kaggle/working/allimages/shoes/8074081.94265.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/7156500.21473.jpg -> /kaggle/working/allimages/shoes/7156500.21473.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074081.1072.jpg -> /kaggle/working/allimages/shoes/8074081.1072.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/7908964.331852.jpg -> /kaggle/working/allimages/shoes/7908964.331852.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/7156500.89.jpg -> /kaggle/working/allimages/shoes/7156500.89.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074097.390231.jpg -> /kaggle/working/allimages/shoes/8074097.390231.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/7966656.646.jpg -> /kaggle/working/allimages/shoes/7966656.646.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074122.132376.jpg -> /kaggle/working/allimages/shoes/8074122.132376.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074122.886.jpg -> /kaggle/working/allimages/shoes/8074122.886.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074098.109831.jpg -> /kaggle/working/allimages/shoes/8074098.109831.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074097.90.jpg -> /kaggle/working/allimages/shoes/8074097.90.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074097.390230.jpg -> /kaggle/working/allimages/shoes/8074097.390230.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074121.390254.jpg -> /kaggle/working/allimages/shoes/8074121.390254.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/7966636.3.jpg -> /kaggle/working/allimages/shoes/7966636.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/7908907.331852.jpg -> /kaggle/working/allimages/shoes/7908907.331852.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Taryn Rose/8074081.212791.jpg -> /kaggle/working/allimages/shoes/8074081.212791.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8090616.61739.jpg -> /kaggle/working/allimages/shoes/8090616.61739.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8090616.589.jpg -> /kaggle/working/allimages/shoes/8090616.589.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8090616.72.jpg -> /kaggle/working/allimages/shoes/8090616.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8028452.72.jpg -> /kaggle/working/allimages/shoes/8028452.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8090625.2992.jpg -> /kaggle/working/allimages/shoes/8090625.2992.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8090625.210516.jpg -> /kaggle/working/allimages/shoes/8090625.210516.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8090625.72.jpg -> /kaggle/working/allimages/shoes/8090625.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8090616.6907.jpg -> /kaggle/working/allimages/shoes/8090616.6907.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Franco Sarto/8090625.113641.jpg -> /kaggle/working/allimages/shoes/8090625.113641.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942126.3.jpg -> /kaggle/working/allimages/shoes/7942126.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942043.182094.jpg -> /kaggle/working/allimages/shoes/7942043.182094.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942036.3.jpg -> /kaggle/working/allimages/shoes/7942036.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7629044.3.jpg -> /kaggle/working/allimages/shoes/7629044.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747405.200.jpg -> /kaggle/working/allimages/shoes/7747405.200.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7629044.767.jpg -> /kaggle/working/allimages/shoes/7629044.767.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747185.3.jpg -> /kaggle/working/allimages/shoes/7747185.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942043.3.jpg -> /kaggle/working/allimages/shoes/7942043.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7746328.14.jpg -> /kaggle/working/allimages/shoes/7746328.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7746329.18.jpg -> /kaggle/working/allimages/shoes/7746329.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7628426.14.jpg -> /kaggle/working/allimages/shoes/7628426.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7628426.3.jpg -> /kaggle/working/allimages/shoes/7628426.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747185.18.jpg -> /kaggle/working/allimages/shoes/7747185.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7746329.3.jpg -> /kaggle/working/allimages/shoes/7746329.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942036.552.jpg -> /kaggle/working/allimages/shoes/7942036.552.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942129.18.jpg -> /kaggle/working/allimages/shoes/7942129.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7629043.3.jpg -> /kaggle/working/allimages/shoes/7629043.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747184.18.jpg -> /kaggle/working/allimages/shoes/7747184.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942129.1892.jpg -> /kaggle/working/allimages/shoes/7942129.1892.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747405.1892.jpg -> /kaggle/working/allimages/shoes/7747405.1892.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7943461.275.jpg -> /kaggle/working/allimages/shoes/7943461.275.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7943460.3.jpg -> /kaggle/working/allimages/shoes/7943460.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942087.3.jpg -> /kaggle/working/allimages/shoes/7942087.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7629043.18.jpg -> /kaggle/working/allimages/shoes/7629043.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747405.767.jpg -> /kaggle/working/allimages/shoes/7747405.767.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7628424.464.jpg -> /kaggle/working/allimages/shoes/7628424.464.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747184.11.jpg -> /kaggle/working/allimages/shoes/7747184.11.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942130.20.jpg -> /kaggle/working/allimages/shoes/7942130.20.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747405.632.jpg -> /kaggle/working/allimages/shoes/7747405.632.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7943461.18.jpg -> /kaggle/working/allimages/shoes/7943461.18.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7943450.14.jpg -> /kaggle/working/allimages/shoes/7943450.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/8023683.2433.jpg -> /kaggle/working/allimages/shoes/8023683.2433.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/8023683.3.jpg -> /kaggle/working/allimages/shoes/8023683.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747405.3.jpg -> /kaggle/working/allimages/shoes/7747405.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747406.3.jpg -> /kaggle/working/allimages/shoes/7747406.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7629043.385.jpg -> /kaggle/working/allimages/shoes/7629043.385.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7942043.20.jpg -> /kaggle/working/allimages/shoes/7942043.20.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7498929.2433.jpg -> /kaggle/working/allimages/shoes/7498929.2433.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7629043.14.jpg -> /kaggle/working/allimages/shoes/7629043.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/8023682.20.jpg -> /kaggle/working/allimages/shoes/8023682.20.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7403242.143549.jpg -> /kaggle/working/allimages/shoes/7403242.143549.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7629044.19.jpg -> /kaggle/working/allimages/shoes/7629044.19.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747409.3.jpg -> /kaggle/working/allimages/shoes/7747409.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7498952.767.jpg -> /kaggle/working/allimages/shoes/7498952.767.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747405.19.jpg -> /kaggle/working/allimages/shoes/7747405.19.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7746328.182094.jpg -> /kaggle/working/allimages/shoes/7746328.182094.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7629044.1892.jpg -> /kaggle/working/allimages/shoes/7629044.1892.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7746331.182094.jpg -> /kaggle/working/allimages/shoes/7746331.182094.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7746328.3.jpg -> /kaggle/working/allimages/shoes/7746328.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/8023682.3.jpg -> /kaggle/working/allimages/shoes/8023682.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7628424.3.jpg -> /kaggle/working/allimages/shoes/7628424.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7498929.3.jpg -> /kaggle/working/allimages/shoes/7498929.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7747185.14.jpg -> /kaggle/working/allimages/shoes/7747185.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Cobian/7498929.4554.jpg -> /kaggle/working/allimages/shoes/7498929.4554.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturino/7919201.6972.jpg -> /kaggle/working/allimages/shoes/7919201.6972.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturino/7899780.3.jpg -> /kaggle/working/allimages/shoes/7899780.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturino/7899780.14.jpg -> /kaggle/working/allimages/shoes/7899780.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturino/7540745.5913.jpg -> /kaggle/working/allimages/shoes/7540745.5913.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturino/7885100.14.jpg -> /kaggle/working/allimages/shoes/7885100.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturino/7919147.4463.jpg -> /kaggle/working/allimages/shoes/7919147.4463.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturino/7930468.9.jpg -> /kaggle/working/allimages/shoes/7930468.9.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980001.15.jpg -> /kaggle/working/allimages/shoes/7980001.15.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7979873.3.jpg -> /kaggle/working/allimages/shoes/7979873.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788849.14.jpg -> /kaggle/working/allimages/shoes/7788849.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788846.47.jpg -> /kaggle/working/allimages/shoes/7788846.47.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980008.72.jpg -> /kaggle/working/allimages/shoes/7980008.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7979987.72.jpg -> /kaggle/working/allimages/shoes/7979987.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788824.43.jpg -> /kaggle/working/allimages/shoes/7788824.43.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980010.589.jpg -> /kaggle/working/allimages/shoes/7980010.589.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7979987.162.jpg -> /kaggle/working/allimages/shoes/7979987.162.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7789400.3093.jpg -> /kaggle/working/allimages/shoes/7789400.3093.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7639878.43.jpg -> /kaggle/working/allimages/shoes/7639878.43.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788846.15.jpg -> /kaggle/working/allimages/shoes/7788846.15.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788824.3.jpg -> /kaggle/working/allimages/shoes/7788824.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7979987.15.jpg -> /kaggle/working/allimages/shoes/7979987.15.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7639914.43.jpg -> /kaggle/working/allimages/shoes/7639914.43.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788849.43.jpg -> /kaggle/working/allimages/shoes/7788849.43.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7789400.11580.jpg -> /kaggle/working/allimages/shoes/7789400.11580.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980010.44.jpg -> /kaggle/working/allimages/shoes/7980010.44.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7639881.162.jpg -> /kaggle/working/allimages/shoes/7639881.162.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980001.44.jpg -> /kaggle/working/allimages/shoes/7980001.44.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7793107.15.jpg -> /kaggle/working/allimages/shoes/7793107.15.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7639878.158.jpg -> /kaggle/working/allimages/shoes/7639878.158.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788824.158.jpg -> /kaggle/working/allimages/shoes/7788824.158.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788849.158.jpg -> /kaggle/working/allimages/shoes/7788849.158.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7979987.687.jpg -> /kaggle/working/allimages/shoes/7979987.687.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980005.44.jpg -> /kaggle/working/allimages/shoes/7980005.44.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788846.84.jpg -> /kaggle/working/allimages/shoes/7788846.84.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7793107.72.jpg -> /kaggle/working/allimages/shoes/7793107.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788846.4.jpg -> /kaggle/working/allimages/shoes/7788846.4.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7793107.589.jpg -> /kaggle/working/allimages/shoes/7793107.589.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980010.72.jpg -> /kaggle/working/allimages/shoes/7980010.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788825.3.jpg -> /kaggle/working/allimages/shoes/7788825.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7639881.216.jpg -> /kaggle/working/allimages/shoes/7639881.216.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788847.15.jpg -> /kaggle/working/allimages/shoes/7788847.15.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7793107.162.jpg -> /kaggle/working/allimages/shoes/7793107.162.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788825.15.jpg -> /kaggle/working/allimages/shoes/7788825.15.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980001.561.jpg -> /kaggle/working/allimages/shoes/7980001.561.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788825.84.jpg -> /kaggle/working/allimages/shoes/7788825.84.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788847.3.jpg -> /kaggle/working/allimages/shoes/7788847.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980001.72.jpg -> /kaggle/working/allimages/shoes/7980001.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7979873.385.jpg -> /kaggle/working/allimages/shoes/7979873.385.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788849.3.jpg -> /kaggle/working/allimages/shoes/7788849.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7639878.764.jpg -> /kaggle/working/allimages/shoes/7639878.764.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980005.72.jpg -> /kaggle/working/allimages/shoes/7980005.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7980010.162.jpg -> /kaggle/working/allimages/shoes/7980010.162.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788848.43.jpg -> /kaggle/working/allimages/shoes/7788848.43.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788847.43.jpg -> /kaggle/working/allimages/shoes/7788847.43.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788824.14.jpg -> /kaggle/working/allimages/shoes/7788824.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7793107.44.jpg -> /kaggle/working/allimages/shoes/7793107.44.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Spring Step/7788848.711.jpg -> /kaggle/working/allimages/shoes/7788848.711.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/8061622.53574.jpg -> /kaggle/working/allimages/shoes/8061622.53574.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/7895611.394069.jpg -> /kaggle/working/allimages/shoes/7895611.394069.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/7895611.8835.jpg -> /kaggle/working/allimages/shoes/7895611.8835.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/8063779.16090.jpg -> /kaggle/working/allimages/shoes/8063779.16090.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/8063767.384898.jpg -> /kaggle/working/allimages/shoes/8063767.384898.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/8063788.1334.jpg -> /kaggle/working/allimages/shoes/8063788.1334.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/7895611.10886.jpg -> /kaggle/working/allimages/shoes/7895611.10886.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/8063779.27751.jpg -> /kaggle/working/allimages/shoes/8063779.27751.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/7932821.79708.jpg -> /kaggle/working/allimages/shoes/7932821.79708.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/7879092.9467.jpg -> /kaggle/working/allimages/shoes/7879092.9467.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/7932822.187914.jpg -> /kaggle/working/allimages/shoes/7932822.187914.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Ralph Lauren Collection/8061622.1165.jpg -> /kaggle/working/allimages/shoes/8061622.1165.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8006165.365556.jpg -> /kaggle/working/allimages/shoes/8006165.365556.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8085606.711.jpg -> /kaggle/working/allimages/shoes/8085606.711.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8128788.408402.jpg -> /kaggle/working/allimages/shoes/8128788.408402.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8085606.621.jpg -> /kaggle/working/allimages/shoes/8085606.621.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8085606.2957.jpg -> /kaggle/working/allimages/shoes/8085606.2957.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8128774.3376.jpg -> /kaggle/working/allimages/shoes/8128774.3376.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8085606.14.jpg -> /kaggle/working/allimages/shoes/8085606.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8128788.11929.jpg -> /kaggle/working/allimages/shoes/8128788.11929.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8085606.7351.jpg -> /kaggle/working/allimages/shoes/8085606.7351.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8085606.50233.jpg -> /kaggle/working/allimages/shoes/8085606.50233.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8085606.3.jpg -> /kaggle/working/allimages/shoes/8085606.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Dirty Laundry/8128788.21287.jpg -> /kaggle/working/allimages/shoes/8128788.21287.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Klogs USA/7919237.334689.jpg -> /kaggle/working/allimages/shoes/7919237.334689.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Klogs USA/7919198.200622.jpg -> /kaggle/working/allimages/shoes/7919198.200622.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Klogs USA/7919237.9543.jpg -> /kaggle/working/allimages/shoes/7919237.9543.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Klogs USA/7919190.200622.jpg -> /kaggle/working/allimages/shoes/7919190.200622.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Klogs USA/7919238.334690.jpg -> /kaggle/working/allimages/shoes/7919238.334690.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Klogs USA/7919238.69989.jpg -> /kaggle/working/allimages/shoes/7919238.69989.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Klogs USA/7919198.370411.jpg -> /kaggle/working/allimages/shoes/7919198.370411.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Klogs USA/7919198.69989.jpg -> /kaggle/working/allimages/shoes/7919198.69989.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Pablosky Kids/7927215.60568.jpg -> /kaggle/working/allimages/shoes/7927215.60568.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Pablosky Kids/8042532.35013.jpg -> /kaggle/working/allimages/shoes/8042532.35013.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141855.19.jpg -> /kaggle/working/allimages/shoes/8141855.19.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141848.3.jpg -> /kaggle/working/allimages/shoes/8141848.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141848.439.jpg -> /kaggle/working/allimages/shoes/8141848.439.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141855.960.jpg -> /kaggle/working/allimages/shoes/8141855.960.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141850.2044.jpg -> /kaggle/working/allimages/shoes/8141850.2044.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141855.35560.jpg -> /kaggle/working/allimages/shoes/8141855.35560.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141850.151.jpg -> /kaggle/working/allimages/shoes/8141850.151.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141853.14.jpg -> /kaggle/working/allimages/shoes/8141853.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141855.3.jpg -> /kaggle/working/allimages/shoes/8141855.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141850.840.jpg -> /kaggle/working/allimages/shoes/8141850.840.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141849.3.jpg -> /kaggle/working/allimages/shoes/8141849.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141849.184651.jpg -> /kaggle/working/allimages/shoes/8141849.184651.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141848.14275.jpg -> /kaggle/working/allimages/shoes/8141848.14275.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141850.960.jpg -> /kaggle/working/allimages/shoes/8141850.960.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Joie/8141850.14.jpg -> /kaggle/working/allimages/shoes/8141850.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Chaco/7725347.3.jpg -> /kaggle/working/allimages/shoes/7725347.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Chaco/7892502.326602.jpg -> /kaggle/working/allimages/shoes/7892502.326602.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Chaco/7934607.340935.jpg -> /kaggle/working/allimages/shoes/7934607.340935.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Chaco/7724986.25735.jpg -> /kaggle/working/allimages/shoes/7724986.25735.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Chaco/7934612.3.jpg -> /kaggle/working/allimages/shoes/7934612.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Chaco/7385739.3.jpg -> /kaggle/working/allimages/shoes/7385739.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Chaco/7725412.3.jpg -> /kaggle/working/allimages/shoes/7725412.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Chaco/7724947.3.jpg -> /kaggle/working/allimages/shoes/7724947.3.jpg
# ...
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturalizer/7894968.327653.jpg -> /kaggle/working/allimages/shoes/7894968.327653.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturalizer/7913317.14.jpg -> /kaggle/working/allimages/shoes/7913317.14.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturalizer/7894968.227828.jpg -> /kaggle/working/allimages/shoes/7894968.227828.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturalizer/7913317.4567.jpg -> /kaggle/working/allimages/shoes/7913317.4567.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturalizer/7913317.72.jpg -> /kaggle/working/allimages/shoes/7913317.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Naturalizer/7894968.72.jpg -> /kaggle/working/allimages/shoes/7894968.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Eastland/7623362.3.jpg -> /kaggle/working/allimages/shoes/7623362.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Eastland/7922684.158.jpg -> /kaggle/working/allimages/shoes/7922684.158.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7970539.374050.jpg -> /kaggle/working/allimages/shoes/7970539.374050.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882477.322718.jpg -> /kaggle/working/allimages/shoes/7882477.322718.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7911268.106.jpg -> /kaggle/working/allimages/shoes/7911268.106.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7945435.77508.jpg -> /kaggle/working/allimages/shoes/7945435.77508.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882489.82.jpg -> /kaggle/working/allimages/shoes/7882489.82.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7945433.32962.jpg -> /kaggle/working/allimages/shoes/7945433.32962.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882485.322725.jpg -> /kaggle/working/allimages/shoes/7882485.322725.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882476.322723.jpg -> /kaggle/working/allimages/shoes/7882476.322723.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882475.322732.jpg -> /kaggle/working/allimages/shoes/7882475.322732.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/8061366.89.jpg -> /kaggle/working/allimages/shoes/8061366.89.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/8061366.37116.jpg -> /kaggle/working/allimages/shoes/8061366.37116.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/8061349.13242.jpg -> /kaggle/working/allimages/shoes/8061349.13242.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882475.322733.jpg -> /kaggle/working/allimages/shoes/7882475.322733.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882478.159015.jpg -> /kaggle/working/allimages/shoes/7882478.159015.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/8064879.82.jpg -> /kaggle/working/allimages/shoes/8064879.82.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882489.1765.jpg -> /kaggle/working/allimages/shoes/7882489.1765.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/7882482.4030.jpg -> /kaggle/working/allimages/shoes/7882482.4030.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Robert Clergerie/8061349.60.jpg -> /kaggle/working/allimages/shoes/8061349.60.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7622682.2123.jpg -> /kaggle/working/allimages/shoes/7622682.2123.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7910089.332214.jpg -> /kaggle/working/allimages/shoes/7910089.332214.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7760542.72.jpg -> /kaggle/working/allimages/shoes/7760542.72.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305950.129040.jpg -> /kaggle/working/allimages/shoes/7305950.129040.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7218880.332482.jpg -> /kaggle/working/allimages/shoes/7218880.332482.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7622682.89.jpg -> /kaggle/working/allimages/shoes/7622682.89.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7218880.316193.jpg -> /kaggle/working/allimages/shoes/7218880.316193.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7506290.342657.jpg -> /kaggle/working/allimages/shoes/7506290.342657.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7506293.121734.jpg -> /kaggle/working/allimages/shoes/7506293.121734.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7374552.129041.jpg -> /kaggle/working/allimages/shoes/7374552.129041.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7374610.185550.jpg -> /kaggle/working/allimages/shoes/7374610.185550.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7343398.316282.jpg -> /kaggle/working/allimages/shoes/7343398.316282.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7760542.11.jpg -> /kaggle/working/allimages/shoes/7760542.11.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7374610.160475.jpg -> /kaggle/working/allimages/shoes/7374610.160475.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7910089.336329.jpg -> /kaggle/working/allimages/shoes/7910089.336329.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7910089.336328.jpg -> /kaggle/working/allimages/shoes/7910089.336328.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7506325.306586.jpg -> /kaggle/working/allimages/shoes/7506325.306586.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7760542.332195.jpg -> /kaggle/working/allimages/shoes/7760542.332195.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305949.4250.jpg -> /kaggle/working/allimages/shoes/7305949.4250.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7374552.342646.jpg -> /kaggle/working/allimages/shoes/7374552.342646.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7374552.82.jpg -> /kaggle/working/allimages/shoes/7374552.82.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305950.10715.jpg -> /kaggle/working/allimages/shoes/7305950.10715.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7343398.316281.jpg -> /kaggle/working/allimages/shoes/7343398.316281.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7910089.250807.jpg -> /kaggle/working/allimages/shoes/7910089.250807.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7374610.160476.jpg -> /kaggle/working/allimages/shoes/7374610.160476.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305950.129041.jpg -> /kaggle/working/allimages/shoes/7305950.129041.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7343398.316283.jpg -> /kaggle/working/allimages/shoes/7343398.316283.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7506293.82.jpg -> /kaggle/working/allimages/shoes/7506293.82.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7506290.342658.jpg -> /kaggle/working/allimages/shoes/7506290.342658.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7506290.316506.jpg -> /kaggle/working/allimages/shoes/7506290.316506.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7506290.316282.jpg -> /kaggle/working/allimages/shoes/7506290.316282.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305949.589.jpg -> /kaggle/working/allimages/shoes/7305949.589.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7218880.336344.jpg -> /kaggle/working/allimages/shoes/7218880.336344.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305949.82.jpg -> /kaggle/working/allimages/shoes/7305949.82.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305949.21944.jpg -> /kaggle/working/allimages/shoes/7305949.21944.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305949.342659.jpg -> /kaggle/working/allimages/shoes/7305949.342659.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7218880.316189.jpg -> /kaggle/working/allimages/shoes/7218880.316189.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7760542.3298.jpg -> /kaggle/working/allimages/shoes/7760542.3298.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7622682.342629.jpg -> /kaggle/working/allimages/shoes/7622682.342629.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305950.332210.jpg -> /kaggle/working/allimages/shoes/7305950.332210.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305950.342661.jpg -> /kaggle/working/allimages/shoes/7305950.342661.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7305949.310.jpg -> /kaggle/working/allimages/shoes/7305949.310.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7910089.89.jpg -> /kaggle/working/allimages/shoes/7910089.89.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7218880.316195.jpg -> /kaggle/working/allimages/shoes/7218880.316195.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7218880.342649.jpg -> /kaggle/working/allimages/shoes/7218880.342649.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7506325.4844.jpg -> /kaggle/working/allimages/shoes/7506325.4844.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7760538.332189.jpg -> /kaggle/working/allimages/shoes/7760538.332189.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7343398.342638.jpg -> /kaggle/working/allimages/shoes/7343398.342638.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Finn Comfort/7257609.278.jpg -> /kaggle/working/allimages/shoes/7257609.278.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Penny Loves Kenny/7999796.934.jpg -> /kaggle/working/allimages/shoes/7999796.934.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Penny Loves Kenny/8128955.2957.jpg -> /kaggle/working/allimages/shoes/8128955.2957.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Penny Loves Kenny/8128955.3.jpg -> /kaggle/working/allimages/shoes/8128955.3.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Penny Loves Kenny/8128955.158.jpg -> /kaggle/working/allimages/shoes/8128955.158.jpg
# Moved: /kaggle/input/large-shoe-dataset-ut-zappos50k/ut-zap50k-images-square/ut-zap50k-images-square/Sandals/Flat/Penny Loves Kenny/8128955.6.jpg -> /kaggle/working/allimages/shoes/8128955.6.jpg
# Reached the limit of 4000 images.

# %%
class CustomDataset(Dataset):
    def __init__(self, img_dir, transform1=None, transform2=None):
    
        self.img_dir = img_dir
        self.img_names = os.listdir(img_dir)
        self.transform1 = transform1
        self.transform2 = transform2
        
        self.imgs = []
        for img_name in self.img_names:
            img = Image.open(os.path.join(img_dir, img_name))
            
            if self.transform1 is not None:
                img = self.transform1(img)
                
            self.imgs.append(img)

    def __getitem__(self, index):
        img = self.imgs[index]
        
        if self.transform2 is not None:
            img = self.transform2(img)
        
        return img

    def __len__(self):
        return len(self.imgs)

# %%
transform1 = transforms.Compose([transforms.Resize(64),
                                transforms.CenterCrop(64)])

# Data augmentation and converting to tensors
random_transforms = [transforms.RandomRotation(degrees=5)]
transform2 = transforms.Compose([transforms.RandomHorizontalFlip(p=0.5),
                                 transforms.RandomApply(random_transforms, p=0.3), 
                                 transforms.ToTensor(),
                                 transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
                                 
train_dataset = CustomDataset(img_dir='/kaggle/working/allimages/shoes',
                           transform1=transform1,
                           transform2=transform2)

train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size,
                          shuffle=True,
                          num_workers=4)

                                           
imgs = next(iter(train_loader))
imgs = imgs.numpy().transpose(0, 2, 3, 1)

# %% [markdown]
# ### Let's see examples of traing data

# %%
fig = plt.figure(figsize=(25, 16))
for ii, img in enumerate(imgs):
    ax = fig.add_subplot(4, 8, ii + 1, xticks=[], yticks=[])
    
    plt.imshow((img+1)/2)

# %% [markdown]
# ## Initialize models and optimizers

# %%
from torchvision.models import alexnet
netD = alexnet(pretrained=True)
netD.classifier = nn.Sequential(
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=9216, out_features=4096, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=4096, out_features=2048, bias=True),
    nn.ReLU(inplace=True),
    nn.Linear(in_features=2048, out_features=1, bias=True),
    nn.Sigmoid()
  )
netD.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# 100%|██████████| 244418560/244418560 [00:01<00:00, 150691037.31it/s]
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=2048, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=2048, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )

# %%
for name, param in netD.named_parameters():
    if param.requires_grad:
        param.requires_grad = False

# %%
for name, param in netD.classifier.named_parameters():
    if ('4' in name) or ('6' in name):
        param.requires_grad = True

# %%
len([p for p in netD.parameters() if p.requires_grad])
# Out:
# 4

# %%
netG = Generator(nz).to(device)
netD = Discriminator().to(device)

criterion = nn.BCELoss()

non_frozen_parameters = [p for p in netD.parameters() if p.requires_grad]
optimizerD = optim.Adam(non_frozen_parameters, lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

fixed_noise = torch.randn(25, nz, 1, 1, device=device)

G_losses = []
D_losses = []
epoch_time = []

# %%
def plot_loss (G_losses, D_losses, epoch):
    plt.figure(figsize=(10,5))
    plt.title("Generator and Discriminator Loss - EPOCH "+ str(epoch))
    plt.plot(G_losses,label="G")
    plt.plot(D_losses,label="D")
    plt.xlabel("iterations")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %%
def show_generated_img(n_images=5):
    sample = []
    for _ in range(n_images):
        noise = torch.randn(1, nz, 1, 1, device=device)
        gen_image = netG(noise).to("cpu").clone().detach().squeeze(0)
        gen_image = gen_image.numpy().transpose(1, 2, 0)
        sample.append(gen_image)
    
    figure, axes = plt.subplots(1, len(sample), figsize = (64,64))
    for index, axis in enumerate(axes):
        axis.axis('off')
        image_array = sample[index]
        axis.imshow(image_array)
        
    plt.show()
    plt.close()

# %% [markdown]
# ## Training loop

# %%
import time
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

# Lists to store losses for plotting later
G_losses = []
D_losses = []

# Hyperparameters for regularization and early stopping
dropout_prob = 0.3  # Dropout probability
l2_lambda = 1e-4  # L2 regularization strength (weight decay)
convergence_threshold = 0.01  # Convergence check threshold (loss change)
patience = 5  # Number of epochs to wait for improvement (early stopping)
no_improvement_count = 0  # Counter for early stopping

# Add Dropout to the networks (assuming you've defined your networks with Dropout layers)
# Example: netD and netG should include Dropout layers in their architecture

# Training loop
for epoch in range(epochs):
    start = time.time()
    
    for ii, real_images in tqdm(enumerate(train_loader), total=len(train_loader)):
        ############################
        # (1) Update D network
        ###########################
        netD.zero_grad()
        real_images = real_images.to(device)
        batch_size = real_images.size(0)
        labels = torch.full((batch_size, 1), real_label, device=device)
        
        # Real images
        outputR = netD(real_images)
        
        # Fake images
        noise = torch.randn(batch_size, nz, 1, 1, device=device)
        fake = netG(noise)
        outputF = netD(fake.detach())
        
        # Discriminator loss
        errD = (torch.mean((outputR - torch.mean(outputF) - labels) ** 2) + 
                torch.mean((outputF - torch.mean(outputR) + labels) ** 2))/2
        errD.backward(retain_graph=True)
        
        # L2 Regularization (weight decay) for discriminator
        for param in netD.parameters():
            errD += l2_lambda * torch.sum(param ** 2)
        
        optimizerD.step()
        
        ############################
        # (2) Update G network
        ###########################
        netG.zero_grad()
        outputF = netD(fake)  # Discriminator output for fake images
        
        # Generator loss
        errG = (torch.mean((outputR - torch.mean(outputF) + labels) ** 2) +
                torch.mean((outputF - torch.mean(outputR) - labels) ** 2))/2
        errG.backward()
        
        # L2 Regularization (weight decay) for generator
        for param in netG.parameters():
            errG += l2_lambda * torch.sum(param ** 2)
        
        optimizerG.step()
        
        # Save Losses for plotting later
        G_losses.append(errG.item())
        D_losses.append(errD.item())
        
        # Print losses every half epoch
        if (ii + 1) % (len(train_loader)//2) == 0:
            print(f'[{epoch+1}/{epochs}] [{ii+1}/{len(train_loader)}] Loss_D: {errD.item():.4f} Loss_G: {errG.item():.4f}')
    
    # Check for convergence and overfitting
    if epoch > 0:
        if abs(G_losses[-1] - G_losses[-2]) < convergence_threshold:
            print(f"Model converged after {epoch+1} epochs")
            break  # Stop training if model has converged

    # Early stopping if no improvement in generator loss
    if epoch > 0 and abs(G_losses[-1] - G_losses[-2]) < convergence_threshold:
        no_improvement_count += 1
        if no_improvement_count >= patience:
            print(f"Early stopping at epoch {epoch+1} due to no improvement in loss")
            break
    else:
        no_improvement_count = 0  # Reset the counter if there was improvement

    # Plot losses and generated images after every 10 epochs
    if epoch % 10 == 0:
        plot_loss(G_losses, D_losses, epoch)
        show_generated_img(3)  # Function to display generated images

    epoch_time = time.time() - start
    print(f'Epoch {epoch+1}/{epochs} completed in {epoch_time:.2f} seconds')

# Function to plot losses
def plot_loss(G_losses, D_losses, epoch):
    plt.figure(figsize=(10,5))
    plt.title(f'Losses during Epoch {epoch+1}')
    plt.plot(G_losses, label='Generator Loss')
    plt.plot(D_losses, label='Discriminator Loss')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# Function to display generated images (you need to define this function based on your setup)
def show_generated_img(num_images=3):
    noise = torch.randn(num_images, nz, 1, 1, device=device)
    fake_images = netG(noise)
    fake_images = fake_images.cpu().detach().numpy()
    
    fig, axs = plt.subplots(1, num_images, figsize=(10, 5))
    for i in range(num_images):
        axs[i].imshow(fake_images[i].transpose(1, 2, 0))
        axs[i].axis('off')
    plt.show()

# After training ends, evaluate final results (plot losses, generated images)
plot_loss(G_losses, D_losses, epoch)
show_generated_img(5)  # Display some generated images at the end

# Model Evaluation
def evaluate_model():
    # Evaluate convergence based on loss trends
    if abs(G_losses[-1] - G_losses[-2]) < convergence_threshold:
        print("The model has likely converged.")
    else:
        print("The model has not converged yet.")
    
    # Check if overfitting occurs: 
    # If discriminator loss is very low and generator loss is high, it's overfitting
    if D_losses[-1] < 0.1 and G_losses[-1] > 1:
        print("Model is likely overfitting. Consider regularization techniques such as dropout, L2 regularization, or early stopping.")
    
    # Check if underfitting occurs: 
    # If the losses are high and not decreasing, it may be underfitting.
    if D_losses[-1] > 1 and G_losses[-1] > 1:
        print("Model is likely underfitting. Consider increasing model capacity or training for more epochs.")
        
    # Output the total number of epochs
    print(f"Total epochs trained: {epoch+1}")

# Call the evaluation function at the end
evaluate_model()
# Out:
#  52%|█████▏    | 65/125 [00:03<00:02, 20.85it/s]
# [1/500] [62/125] Loss_D: 0.4756 Loss_G: 1.0176
# 100%|██████████| 125/125 [00:06<00:00, 20.89it/s]
# [1/500] [124/125] Loss_D: 0.2196 Loss_G: 1.5694
# Epoch 1/500 completed in 6.68 seconds
#  52%|█████▏    | 65/125 [00:03<00:02, 20.76it/s]
# [2/500] [62/125] Loss_D: 0.4395 Loss_G: 2.2070
# 100%|██████████| 125/125 [00:06<00:00, 20.83it/s]
# [2/500] [124/125] Loss_D: 0.2311 Loss_G: 1.5071
# Epoch 2/500 completed in 6.16 seconds
#  52%|█████▏    | 65/125 [00:03<00:02, 20.84it/s]
# [3/500] [62/125] Loss_D: 0.1512 Loss_G: 1.9624
# 100%|██████████| 125/125 [00:06<00:00, 20.89it/s]
# [3/500] [124/125] Loss_D: 0.1400 Loss_G: 2.1306
# Epoch 3/500 completed in 6.16 seconds
#  52%|█████▏    | 65/125 [00:03<00:02, 20.75it/s]
# [4/500] [62/125] Loss_D: 0.2130 Loss_G: 2.9774
# 100%|██████████| 125/125 [00:06<00:00, 20.84it/s]
# [4/500] [124/125] Loss_D: 0.2609 Loss_G: 2.1878
# Epoch 4/500 completed in 6.17 seconds
#  52%|█████▏    | 65/125 [00:03<00:02, 20.81it/s]
# [5/500] [62/125] Loss_D: 0.2499 Loss_G: 2.9743
# 100%|██████████| 125/125 [00:06<00:00, 20.84it/s]
# [5/500] [124/125] Loss_D: 0.2013 Loss_G: 2.1954
# Epoch 5/500 completed in 6.17 seconds
#  52%|█████▏    | 65/125 [00:03<00:02, 20.83it/s]
# [6/500] [62/125] Loss_D: 0.2981 Loss_G: 2.0742
# 100%|██████████| 125/125 [00:06<00:00, 20.89it/s]
# [6/500] [124/125] Loss_D: 0.2931 Loss_G: 1.8170
# Epoch 6/500 completed in 6.18 seconds
#  52%|█████▏    | 65/125 [00:03<00:02, 20.85it/s]
# [7/500] [62/125] Loss_D: 0.2903 Loss_G: 2.2397
# 100%|██████████| 125/125 [00:06<00:00, 20.86it/s]
# [7/500] [124/125] Loss_D: 0.3134 Loss_G: 1.6957
# Model converged after 7 epochs
# The model has likely converged.
# Total epochs trained: 7

# %% [markdown]
# ## Let's visualise generated results

# %%
gen_z = torch.randn(32, nz, 1, 1, device=device)
gen_images = (netG(gen_z).to("cpu").clone().detach() + 1)/2
gen_images = gen_images.numpy().transpose(0, 2, 3, 1)

# %%
fig = plt.figure(figsize=(25, 16))
for ii, img in enumerate(gen_images):
    ax = fig.add_subplot(4, 8, ii + 1, xticks=[], yticks=[])
    plt.imshow(img)

# %% [markdown]
# ## Make predictions and submit

# %%
# import matplotlib.pyplot as plt

# def evaluate_model_performance(train_losses, val_losses, train_accuracies, val_accuracies, max_epochs):
#     # 1. Plot training and validation losses
#     plt.figure(figsize=(12, 6))
#     plt.subplot(1, 2, 1)
#     plt.plot(range(1, max_epochs + 1), train_losses, label='Training Loss')
#     plt.plot(range(1, max_epochs + 1), val_losses, label='Validation Loss')
#     plt.xlabel('Epochs')
#     plt.ylabel('Loss')
#     plt.title('Training and Validation Loss')
#     plt.legend()

#     # 2. Plot training and validation accuracies
#     plt.subplot(1, 2, 2)
#     plt.plot(range(1, max_epochs + 1), train_accuracies, label='Training Accuracy')
#     plt.plot(range(1, max_epochs + 1), val_accuracies, label='Validation Accuracy')
#     plt.xlabel('Epochs')
#     plt.ylabel('Accuracy')
#     plt.title('Training and Validation Accuracy')
#     plt.legend()

#     plt.tight_layout()
#     plt.show()

#     # 3. Convergence check (if loss has stabilized)
#     if val_losses[-1] < val_losses[0] * 0.1:  # A simple condition for convergence
#         print("Model has converged.")
#     else:
#         print("Model has not fully converged.")

#     # 4. Check for overfitting or underfitting
#     if train_losses[-1] < val_losses[-1] and train_accuracies[-1] > val_accuracies[-1]:
#         print("Model is likely overfitting. Consider using regularization, dropout, or early stopping.")
#     elif train_losses[-1] > val_losses[-1] and train_accuracies[-1] < val_accuracies[-1]:
#         print("Model is underfitting. Consider using a more complex model, more epochs, or better features.")
#     else:
#         print("Model appears to be balanced, no immediate signs of overfitting or underfitting.")

#     # 5. How many epochs required for convergence (early stopping)
#     epoch_for_convergence = len([x for x in range(1, len(val_losses)) if val_losses[x] <= val_losses[x - 1]])
#     print(f"Model converged after {epoch_for_convergence} epochs.")

# # # Example usage
# # train_losses = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4]  # Example training losses
# # val_losses = [1.0, 0.9, 0.85, 0.8, 0.75, 0.74]  # Example validation losses
# # train_accuracies = [0.5, 0.6, 0.65, 0.7, 0.75, 0.8]  # Example training accuracies
# # val_accuracies = [0.45, 0.55, 0.6, 0.65, 0.7, 0.75]  # Example validation accuracies
# # max_epochs = 6  # Total number of epochs

# evaluate_model_performance(train_losses, val_losses, train_accuracies, val_accuracies, max_epochs)
